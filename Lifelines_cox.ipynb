# %%
import pandas as pd
import numpy as np
import lifelines
# %matplotlib inline

# %%
#data = lifelines.datasets.load_dd()
rossi_data = pd.read_csv("Rossi.csv")
rossi_data.head()
# Out:
#    Unnamed: 0  week  arrest  fin  age   race wexp          mar paro  prio  \
# 0           1    20       1   no   27  black   no  not married  yes     3
# 1           2    17       1   no   18  black   no  not married  yes     8
# 2           3    25       1   no   19  other  yes  not married  yes    13
# 3           4    52       0  yes   23  black  yes      married  yes     1
# 4           5    52       0   no   19  other  yes  not married  yes     3
#
#    ...   emp43 emp44 emp45 emp46 emp47 emp48 emp49 emp50 emp51 emp52
# 0  ...     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1  ...     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2  ...     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3  ...     yes   yes   yes   yes   yes   yes   yes   yes   yes   yes
# 4  ...      no    no    no    no    no    no    no    no    no    no
#
# [5 rows x 63 columns]

# %%
from lifelines.datasets import load_rossi
from lifelines import CoxPHFitter

rossi_dataset = load_rossi()
cf = CoxPHFitter()
cf.fit(rossi_dataset, 'week', event_col='arrest')

cf.print_summary()  # access the results using cf.summary
# Out:
# n=432, number of events=114
#
#            coef  exp(coef)  se(coef)          z         p  lower 0.95  upper 0.95
# fin  -1.897e-01  8.272e-01 9.579e-02 -1.981e+00 4.763e-02  -3.775e-01  -1.938e-03   *
# age  -3.500e-01  7.047e-01 1.344e-01 -2.604e+00 9.210e-03  -6.134e-01  -8.651e-02  **
# race  1.032e-01  1.109e+00 1.012e-01  1.020e+00 3.078e-01  -9.516e-02   3.015e-01
# wexp -7.486e-02  9.279e-01 1.051e-01 -7.124e-01 4.762e-01  -2.809e-01   1.311e-01
# mar  -1.421e-01  8.675e-01 1.254e-01 -1.134e+00 2.570e-01  -3.880e-01   1.037e-01
# paro -4.134e-02  9.595e-01 9.522e-02 -4.341e-01 6.642e-01  -2.280e-01   1.453e-01
# prio  2.639e-01  1.302e+00 8.291e-02  3.182e+00 1.460e-03   1.013e-01   4.264e-01  **
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Concordance = 0.640
# /Users/Alun/Projects/survival27/lib/python2.7/site-packages/lifelines/fitters/coxph_fitter.py:285: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   df.sort(duration_col, inplace=True)

# %%
rossi_dataset.head()
# Out:
#    week  arrest  fin  age  race  wexp  mar  paro  prio
# 0    20       1    0   27     1     0    0     1     3
# 1    17       1    0   18     1     0    0     1     8
# 2    25       1    0   19     0     1    0     1    13
# 3    52       0    1   23     1     1    1     1     1
# 4    52       0    0   19     0     1    0     1     3
